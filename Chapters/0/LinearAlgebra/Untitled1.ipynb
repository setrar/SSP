# %%
import numpy as np

# %%
A = np.random.rand(3,5)
B = np.random.rand(5,2)
M = np.empty((3,2))

total = [[[total + A[i,k]*B[k,j] for k in range(5)] for j in range(2)] for i in range(3)]
display(total)
# Out:
# [[[array([[[0.650573  , 0.87480315, 0.64041053, 0.99262921, 1.05106431],
#            [0.66508983, 0.64823902, 0.6311042 , 1.24049019, 1.17948936]],
#
#           [[0.7097528 , 0.73756461, 0.77069957, 0.64523989, 1.01017093],
#            [0.75042484, 0.6319502 , 0.70794062, 0.66342985, 1.12647672]],
#
#           [[0.84714038, 1.01631645, 0.94340151, 0.64885678, 0.86445219],
#            [0.94853248, 0.66503521, 0.80978955, 0.66943798, 0.9375724 ]]]),
#    array([[[0.0461511 , 0.27038124, 0.03598863, 0.3882073 , 0.44664241],
#            [0.06066793, 0.04381712, 0.0266823 , 0.63606829, 0.57506746]],
#
#           [[0.1053309 , 0.13314271, 0.16627767, 0.04081799, 0.40574903],
#            [0.14600293, 0.0275283 , 0.10351872, 0.05900795, 0.52205481]],
#
#           [[0.24271848, 0.41189454, 0.33897961, 0.04443487, 0.26003029],
#            [0.34411057, 0.06061331, 0.20536765, 0.06501607, 0.33315049]]]),
#    array([[[0.32208881, 0.54631895, 0.31192634, 0.66414501, 0.72258012],
# ...

# %%
# Example: Creating a 3D matrix using double-nested list comprehension
matrix_3d = [[[i * 4 + j * 2 + k for k in range(2)] for j in range(3)] for i in range(2)]
print(matrix_3d)
# Out:
# [[[0, 1], [2, 3], [4, 5]], [[4, 5], [6, 7], [8, 9]]]
