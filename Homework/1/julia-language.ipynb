# %%
@time using Plots   # 2.7 seconds
@time plot(1:4)     # 0.14 seconds
# Out:
#   1.007487 seconds (1.05 M allocations: 68.850 MiB, 9.93% gc time, 1.19% compilation time)
#   0.050206 seconds (16.37 k allocations: 1.105 MiB, 96.89% compilation time: 20% of which was recompilation)

# %% [markdown]
# # References
# - [ ] [Is the Julia Language Worth Learning? (Pros and Cons)](https://www.matecdev.com/posts/julia-worth-learning.html)
