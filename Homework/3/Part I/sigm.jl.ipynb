# %%
include("sigm.jl")
# Out:
# sig (generic function with 2 methods)

# %%
# Generate the signal
N = 8
y = sig(N);
# Out:
# t = 1:8

# %%
using Plots

# %%
# Plot the signal
plot(sig(256)
    , label = "Signal"
    , xlabel = "Sample", ylabel = "Amplitude"
    , title = "Generated Signal"
)
# Out:
# t = 1:256
