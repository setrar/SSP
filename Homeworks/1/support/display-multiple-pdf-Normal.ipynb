# %%
using StatsPlots: plot
using Distributions: Normal, pdf

# %%
𝑵(m,sd) = Normal(m, sd)
# Out:
# 𝑵 (generic function with 1 method)

# %%
# Define multiple probability distributions
N₁ = 𝑵(0, 1)
N₂ = 𝑵(2, 0.5)
N₃ = 𝑵(-2, 0.8);

# %%
# Generate sample data from the distributions
X = range(-5.0, stop=5, length=100)
y₁ = pdf.(N₁, X)
y₂ = pdf.(N₂, X)
y₃ = pdf.(N₃, X);

# %%
# Plot the densities
plot( X, y₁, label="Distribution N₁", linewidth=2)
plot!(X, y₂, label="Distribution N₂", linewidth=2)
plot!(X, y₃, label="Distribution N₃", linewidth=2, legend =:topright)

# Customize the plot
xlabel!("X-axis")
ylabel!("Probability Density")
title!("Multiple Probability Distributions")
