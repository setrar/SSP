# %%
using Plots; gr() # for interactivity

# Define points for a surface
x = [0, 1, 0, 1, 0.5]
y = [0, 1, 1, 0, 0.5]
z = [0, 1, 0, 0.5, 1]

# Create a surface plot
surface(x, y, z)

# %%
using Plots; gr()

# Define points for the plane
x = [0, 1]
y = [0, 1]
z = [0 0; 1 1]  # Heights at the corners of the plane

# Create a Mesh object for the surface (plane)
surface(x, y, z)
